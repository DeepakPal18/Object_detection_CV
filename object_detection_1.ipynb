# %%
# !pip install ultralytics==8.0.196
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.2.0+cpu CPU (Intel Core(TM) i5-7200U 2.50GHz)
# Setup complete  (4 CPUs, 7.9 GB RAM, 98.4/125.3 GB disk)

# %%
from ultralytics import YOLO
import cv2
import cvzone
import time
import math

# %%
# getting stuck - 
# model = YOLO('yolov8n.pt')
# result = model(r'C:\Users\Dell\Downloads\Analysis\project9-Object_detection\img.jpg',show=True)
# # cv2.waitKey(0)
# key = cv2.waitKey(0)
# if key == ord('d'):  # Check if the key pressed is 'd'
#     cv2.destroyAllWindows()

# %% [markdown]
# # With Image -

# %%
# note - we have various versions with weights nano,medium,large - 'yolov8l.pt'
# model = YOLO('yolov8n.pt') # instead of downloading everytime just give the path of downloaded file
model = YOLO(r'C:\Users\Dell\Downloads\Analysis\project9-Object_detection\yolov8n.pt')
result = model(r'C:\Users\Dell\Downloads\Analysis\project9-Object_detection\img.jpg', show=True)
# Add a small delay (e.g., 100 milliseconds) before waiting for a key press
# cv2.waitKey(100)
cv2.waitKey(0)  
cv2.destroyAllWindows()
# Out:
# image 1/1 C:\Users\Dell\Downloads\Analysis\project9-Object_detection\img.jpg: 448x640 13 persons, 7 cars, 1 truck, 281.3ms
# Speed: 7.2ms preprocess, 281.3ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)

# %% [markdown]
# # With Webcam -

# %%
# without labels - 
cap = cv2.VideoCapture(0)
cap.set(3,1200)
cap.set(4,720)
model = YOLO(r'C:\Users\Dell\Downloads\Analysis\project9-Object_detection\yolov8n.pt')

while True:
    success,img = cap.read()
    result = model(img ,stream=True)
    for r in result:
        boxes = r.boxes
        for box in boxes:
            x1,y1,x2,y2 = box.xyxy[0]
            x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            print(x1,y1,x2,y2)
            cv2.rectangle(img,(x1,y1),(x2,y2),(0,200,0),3) # img points,color,thickness of box
    cv2.imshow('Image',img)
    # Wait for a key press, and break the loop if any key is pressed
    key = cv2.waitKey(1) & 0xFF
    if key != 255:  # Check if any key is pressed (not equal to 255)
        break

# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 165.5ms
# Speed: 4.4ms preprocess, 165.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 210 119 865 534
# 0: 384x640 1 person, 216.1ms
# Speed: 10.1ms preprocess, 216.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 182 137 787 535
# 0: 384x640 1 person, 156.7ms
# Speed: 12.0ms preprocess, 156.7ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
# 174 141 765 535
# 0: 384x640 1 person, 183.5ms
# Speed: 10.9ms preprocess, 183.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 137.1ms
# 172 136 759 535
# 170 134 756 535
# Speed: 3.1ms preprocess, 137.1ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 155.8ms
# Speed: 1.4ms preprocess, 155.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.3ms
# ...

# %%
# with labes and cvzone - 
cap = cv2.VideoCapture(0)
cap.set(3,680)
cap.set(4,480)
model = YOLO(r'C:\Users\Dell\Downloads\Analysis\project9-Object_detection\yolov8n.pt')

while True:
    success,img = cap.read()
    result = model(img ,stream=True)
    for r in result:
        boxes = r.boxes
        for box in boxes:
            #x1,y1,x2,y2 = box.xyxy[0]
            #x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            #cv2.rectangle(img(x1,y1),(x2,y2),(0,200,0),3) # img points,color,thickness of box
            
            # using cvzone - 
            x1,y1,x2,y2 = box.xyxy[0]
            x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            w,h = x2-x1,y2-y1
            cvzone.cornerRect(img,(x1,y1,w,h))
    cv2.imshow('Image',img)
    # Wait for a key press, and break the loop if any key is pressed
    key = cv2.waitKey(1) & 0xFF
    if key != 255:  # Check if any key is pressed (not equal to 255)
        break

# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 persons, 207.4ms
# Speed: 14.9ms preprocess, 207.4ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 216.0ms
# Speed: 13.1ms preprocess, 216.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 201.3ms
# Speed: 3.0ms preprocess, 201.3ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 186.9ms
# Speed: 3.0ms preprocess, 186.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 195.8ms
# Speed: 2.9ms preprocess, 195.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 182.4ms
# Speed: 3.0ms preprocess, 182.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 184.1ms
# Speed: 3.0ms preprocess, 184.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.2ms
# ...

# %%
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# %%
# with confidence levels - 
cap = cv2.VideoCapture(0)
cap.set(3,680)
cap.set(4,480)
model = YOLO(r'C:\Users\Dell\Downloads\Analysis\project9-Object_detection\yolov8n.pt')

while True:
    success,img = cap.read()
    result = model(img ,stream=True)
    for r in result:
        boxes = r.boxes
        for box in boxes:
            #x1,y1,x2,y2 = box.xyxy[0]
            #x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            #cv2.rectangle(img(x1,y1),(x2,y2),(0,200,0),3) # img points,color,thickness of box
            
            # for bounding box (using cvzone) - 
            x1,y1,x2,y2 = box.xyxy[0]
            x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            w,h = x2-x1,y2-y1
            cvzone.cornerRect(img,(x1,y1,w,h))
            # for confidence level - 
            conf = math.ceil((box.conf[0]*100))/100
            print(conf)
            #put the confidence level text up the boundry box
            # setting the display position of confidence levels
            cvzone.putTextRect(img,f'{conf}',(max(0,x1),max(25,y1)))
             
            
            
    cv2.imshow('Image',img)
    # Wait for a key press, and break the loop if any key is pressed
    key = cv2.waitKey(1) & 0xFF
    if key != 255:  # Check if any key is pressed (not equal to 255)
        break

# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 187.8ms
# Speed: 12.3ms preprocess, 187.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 0.91
# 0: 480x640 1 person, 235.6ms
# Speed: 32.2ms preprocess, 235.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 0.93
# 0: 480x640 1 person, 183.8ms
# Speed: 5.0ms preprocess, 183.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# 0.94
# 0: 480x640 1 person, 231.0ms
# Speed: 0.0ms preprocess, 231.0ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
# 0.94
# 0: 480x640 1 person, 177.8ms
# Speed: 5.0ms preprocess, 177.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 0.93
# 0: 480x640 1 person, 191.0ms
# Speed: 5.8ms preprocess, 191.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# 0.93
# 0: 480x640 1 person, 205.6ms
# Speed: 3.0ms preprocess, 205.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# 0.93
# 0: 480x640 1 person, 231.6ms
# ...

# %%
# with class - 
cap = cv2.VideoCapture(0)
cap.set(3,1200)
cap.set(4,720)
model = YOLO(r'C:\Users\Dell\Downloads\Analysis\project9-Object_detection\yolov8n.pt')

while True:
    success,img = cap.read()
    result = model(img ,stream=True)
    for r in result:
        boxes = r.boxes
        for box in boxes:
            #x1,y1,x2,y2 = box.xyxy[0]
            #x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            #cv2.rectangle(img(x1,y1),(x2,y2),(0,200,0),3) # img points,color,thickness of box
            
            # for bounding box (using cvzone) - 
            x1,y1,x2,y2 = box.xyxy[0]
            x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            w,h = x2-x1,y2-y1
            cvzone.cornerRect(img,(x1,y1,w,h))
            # for confidence level - 
            conf = math.ceil((box.conf[0]*100))/100
            # for class - 
            cls = int(box.cls[0])
            cvzone.putTextRect(img,f'{classNames[cls]} {conf}',(max(0,x1),max(25,y1)))# ,scale=0.7,thickness=1
             
            
            
    cv2.imshow('Image',img)
    # Wait for a key press, and break the loop if any key is pressed
    key = cv2.waitKey(1) & 0xFF
    if key != 255:  # Check if any key is pressed (not equal to 255)
        break

# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 182.5ms
# Speed: 5.2ms preprocess, 182.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 206.9ms
# Speed: 57.7ms preprocess, 206.9ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 197.4ms
# Speed: 4.5ms preprocess, 197.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.0ms
# Speed: 1.0ms preprocess, 174.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 145.5ms
# Speed: 4.1ms preprocess, 145.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.2ms
# Speed: 4.1ms preprocess, 162.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 185.5ms
# Speed: 3.5ms preprocess, 185.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 160.9ms
# ...

# %% [markdown]
# # Object detection in videos -

# %%
cap = cv2.VideoCapture(r"C:\Users\Dell\Downloads\Analysis\project9-Object_detection\vid.mp4") # path
#not required for video - 
# cap.set(3,1200)
# cap.set(4,720)
model = YOLO(r'C:\Users\Dell\Downloads\Analysis\project9-Object_detection\yolov8n.pt')

while True:
    success,img = cap.read()
    result = model(img ,stream=True)
    for r in result:
        boxes = r.boxes
        for box in boxes:
            #x1,y1,x2,y2 = box.xyxy[0]
            #x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            #cv2.rectangle(img(x1,y1),(x2,y2),(0,200,0),3) # img points,color,thickness of box
            
            # for bounding box (using cvzone) - 
            x1,y1,x2,y2 = box.xyxy[0]
            x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            w,h = x2-x1,y2-y1
            cvzone.cornerRect(img,(x1,y1,w,h))
            # for confidence level - 
            conf = math.ceil((box.conf[0]*100))/100
            # for class - 
            cls = int(box.cls[0])
            cvzone.putTextRect(img,f'{classNames[cls]} {conf}',(max(0,x1),max(25,y1)))# ,scale=0.7,thickness=1
             
            
            
    cv2.imshow('Image',img)
    # Wait for a key press, and break the loop if any key is pressed
    key = cv2.waitKey(1) & 0xFF
    if key != 255:  # Check if any key is pressed (not equal to 255)
        break

# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 8 persons, 1 car, 1 bench, 221.9ms
# Speed: 20.6ms preprocess, 221.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bench, 277.8ms
# Speed: 25.2ms preprocess, 277.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bench, 154.3ms
# Speed: 10.4ms preprocess, 154.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bench, 175.2ms
# Speed: 0.0ms preprocess, 175.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 156.2ms
# Speed: 8.7ms preprocess, 156.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 cars, 153.7ms
# Speed: 8.0ms preprocess, 153.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 183.7ms
# ...
